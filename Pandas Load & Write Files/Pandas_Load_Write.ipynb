# %%
import pandas as pd

# Read CSV file into DataFrame
df = pd.read_csv('drinks.csv',header=None)
df
# Out:
#                0              1                2              3  \
# 0        country  beer_servings  spirit_servings  wine_servings
# 1    Afghanistan              0                0              0
# 2        Albania             89              132             54
# 3        Algeria             25                0             14
# 4        Andorra            245              138            312
# ..           ...            ...              ...            ...
# 189    Venezuela            333              100              3
# 190      Vietnam            111                2              1
# 191        Yemen              6                0              0
# 192       Zambia             32               19              4
# 193     Zimbabwe             64               18              4
#
#                                 4              5
# 0    total_litres_of_pure_alcohol      continent
# 1                             0.0           Asia
# ...

# %%
# Write DataFrame to CSV File with Default params.
df3=df.to_csv("H:/courses.csv")

# %%
# Read Excel file
# df = pd.read_excel('c:/apps/courses_schedule.xlsx')
# print(df)

# %%
# Write DataFrame to Excel file
# df.to_excel('Courses.xlsx')

# %%
# Read text file
# df = pd.read_fwf('/Users/admin/apps/proverbs.txt')
# print(df)
